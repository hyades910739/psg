# %% [markdown]
# ## 1. X軸雙變項作圖（折線圖、長條圖）

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# 調整作圖大小
fig = plt.figure(figsize=(4,3))

x = [1,2,3,4,5]
y = [123,432,823,192,12]
x2 = [1,2,3,4,5]
y2 = [432,12,432,847,223]

plt.plot(x,y,'-')
plt.plot(x2,y2,'-')

plt.show()

# %%
import matplotlib.pyplot as plt
plt.style.use('classic')
fig=plt.figure(figsize=(4,3))
x=[1,2,3,4,5]
y=[123,432,823,192,12]
x2=[1,2,3,4,5]
y2=[432,12,432,847,223]
plt.plot(x,y,'-')
plt.plot(x2,y2,'-')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.style.use('ggplot')

fig = plt.figure(figsize=(4,3))

x = [1,2,3,4,5]
y = [123,432,823,192,12]
x2 = [1,2,3,4,5]
y2 = [432,12,432,847,223]

plt.bar(np.array(x)-0.2,y,color = 'g',width=0.4,align='center')
plt.bar(np.array(x2)+0.2,y2,color = 'b',width=0.4,align='center')
plt.show()

# %% [markdown]
# ## 2. 作圖風格

# %% [markdown]
# ##### 查查看所有的風格選擇

# %%
print(plt.style.available)
# Out:
# ['classic', 'seaborn-ticks', 'seaborn-poster', 'seaborn-colorblind', 'seaborn-pastel', 'seaborn-notebook', 'seaborn-dark', 'seaborn-dark-palette', 'seaborn-muted', 'seaborn-whitegrid', 'ggplot', 'fivethirtyeight', 'seaborn-deep', 'dark_background', 'bmh', 'seaborn-darkgrid', 'seaborn-bright', 'seaborn-paper', 'grayscale', 'seaborn-talk', 'seaborn-white']

# %%
plt.style.use('dark_background')

fig = plt.figure(figsize=(4,3))

x = [1,2,3,4,5]
y = [123,432,823,192,12]

plt.bar(x,y,align='center')
plt.show()

# %%
plt.style.use('grayscale')

fig = plt.figure(figsize=(4,3))

x = [1,2,3,4,5]
y = [123,432,823,192,12]

plt.bar(x,y,align='center')
plt.show()

# %%
plt.style.use('classic')

fig = plt.figure(figsize=(4,3))

x = [1,2,3,4,5]
y = [123,432,823,192,12]

plt.bar(x,y,align='center')
plt.show()

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')

fig = plt.figure(figsize=(4,3))

x = [1,2,3,4,5]
y = [123,432,823,192,12]

plt.bar(x,y,align='center')
plt.show()

# %% [markdown]
# ## 3. 標題、X、Y軸名稱（中文處理與字體選擇）

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')

fig = plt.figure(figsize=(4,3))
x = [1,2,3,4,5]
y = [123,432,823,192,12]

plt.rcParams['font.family']='SimHei' #使用中文字體（黑體）

plt.bar(x,y,align='center')
plt.title('中文標題') #標題名稱
plt.xlabel('X軸') #X軸名稱
plt.ylabel('Y軸') #Y軸名稱
plt.xticks(x, ['刻度A','刻度B','刻度C','刻度D','刻度E']) #X軸刻度名稱

plt.show()

# %%
import matplotlib
[f.name for f in matplotlib.font_manager.fontManager.ttflist]
# Out:
# ['Bitstream Vera Sans Mono',
#  'Bitstream Vera Sans Mono',
#  'Bitstream Vera Sans',
#  'cmss10',
#  'STIXGeneral',
#  'Bitstream Vera Sans Mono',
#  'Bitstream Vera Serif',
#  'STIXSizeThreeSym',
#  'STIXNonUnicode',
#  'Bitstream Vera Sans',
#  'cmsy10',
#  'STIXSizeFourSym',
#  'STIXNonUnicode',
#  'Bitstream Vera Serif',
#  'Bitstream Vera Sans Mono',
#  'STIXSizeTwoSym',
#  'STIXGeneral',
#  'STIXSizeThreeSym',
#  'STIXGeneral',
#  'cmtt10',
#  'Bitstream Vera Sans',
#  'STIXSizeFourSym',
#  'Bitstream Vera Sans',
#  'STIXSizeOneSym',
#  'cmb10',
#  'STIXNonUnicode',
#  'STIXSizeTwoSym',
#  'STIXGeneral',
#  'cmmi10',
#  'cmr10',
#  'cmex10',
#  'STIXSizeFiveSym',
#  'STIXNonUnicode',
#  'STIXSizeOneSym',
#  'Adobe Fan Heiti Std',
#  'Adobe Garamond Pro',
#  'Arial Rounded MT Bold',
#  'STIXNonUnicode',
#  'Prestige Elite Std',
#  '.SF Compact Display',
#  'Arial Narrow',
#  'Cambria',
#  'Chaparral Pro',
#  'MingLiU_HKSCS',
#  '.SF Compact Display',
#  'Myriad Pro',
#  'Candara',
#  'System Font',
#  'Lao Sangam MN',
#  'Kozuka Mincho Pr6N',
#  'Nueva Std',
#  'Franklin Gothic Medium',
#  'MS Reference Sans Serif',
#  'Adobe Caslon Pro',
#  'Lucida Sans Unicode',
#  '.SF NS Text Condensed',
#  '.SF Compact Display',
#  'STIXSizeTwoSym',
#  'Kozuka Gothic Pr6N',
#  'Kozuka Gothic Pr6N',
#  'Webdings',
#  'STIXIntegralsSm',
#  'Adobe Caslon Pro',
#  'Nueva Std',
#  'Myriad Arabic',
#  'Verdana',
#  'Kozuka Gothic Pr6N',
#  'Kozuka Mincho Pro',
#  'STIXSizeThreeSym',
#  'Arial',
#  'Kozuka Mincho Pro',
#  'Adobe Garamond Pro',
#  'OCR A Std',
#  'DIN Alternate',
#  'Minion Pro',
#  'Trebuchet MS',
#  'Times New Roman',
#  '.SF NS Display Condensed',
#  'Chaparral Pro',
#  'Minion Pro',
#  'Courier New',
#  'Gurmukhi MT',
#  'Myriad Pro',
#  'Microsoft JhengHei',
#  'Arial',
#  'Constantia',
#  'Myriad Arabic',
#  'Minion Pro',
#  '.SF NS Text Condensed',
#  'Gill Sans MT',
#  'Adobe Fangsong Std',
#  'STIXSizeFiveSym',
#  'Myriad Pro',
#  '.SF Compact Display',
#  'Perpetua',
#  'Arial Black',
#  'Bradley Hand',
#  'Bodoni Ornaments',
#  'Plantagenet Cherokee',
#  'SimSun',
#  'STIXSizeFourSym',
#  'Verdana',
#  'STIXVariants',
#  'Corbel',
#  'Palatino Linotype',
#  'Myriad Pro',
#  'Impact',
#  'Palatino Linotype',
#  'Mesquite Std',
#  'STIXNonUnicode',
#  'STIXIntegralsD',
#  'Kozuka Gothic Pro',
#  'Luminari',
#  'Tekton Pro',
#  'STIXIntegralsD',
#  '.SF NS Text Condensed',
#  '.Keyboard',
#  'InaiMathi',
#  'Meiryo',
#  'Arial',
#  'Chaparral Pro',
#  'Consolas',
#  'STIXSizeThreeSym',
#  'PMingLiU',
#  'Letter Gothic Std',
#  'Arial Unicode MS',
#  'Apple Braille',
#  'Myriad Hebrew',
#  'Birch Std',
#  'Kokonor',
#  'STIXGeneral',
#  'Herculanum',
#  '.SF Compact Rounded',
#  'Adobe Arabic',
#  'Wingdings 3',
#  'Corbel',
#  'Gabriola',
#  'Corbel',
#  'Poplar Std',
#  'Cambria',
#  'Myriad Hebrew',
#  'Perpetua',
#  'Adobe Heiti Std',
#  'System Font',
#  'Calibri',
#  'Myriad Arabic',
#  'STIXSizeTwoSym',
#  'Batang',
#  'STIXSizeOneSym',
#  'Candara',
#  'Arial',
#  'Lucida Console',
#  'Cooper Std',
#  'Consolas',
#  'Trebuchet MS',
#  '.SF NS Display Condensed',
#  'Minion Pro',
#  'Franklin Gothic Book',
#  'Letter Gothic Std',
#  'Candara',
#  'Apple Braille',
#  'Tw Cen MT',
#  'Kozuka Mincho Pr6N',
#  '.SF NS Display Condensed',
#  'Adobe Arabic',
#  'Perpetua',
#  'AppleGothic',
#  'Meiryo',
#  'Adobe Devanagari',
#  '.SF Compact Text',
#  'MingLiU-ExtB',
#  'Wingdings',
#  'Cambria',
#  'Orator Std',
#  'Giddyup Std',
#  'Times New Roman',
#  '.SF Compact Display',
#  'Verdana',
#  'Adobe Garamond Pro',
#  '.SF Compact Text',
#  'Minion Pro',
#  'Verdana',
#  '.SF Compact Text',
#  'Adobe Devanagari',
#  'Arial Narrow',
#  'Kozuka Mincho Pr6N',
#  'Apple Braille',
#  'Perpetua',
#  'Kozuka Gothic Pro',
#  'Myriad Pro',
#  '.SF Compact Text',
#  'Orator Std',
#  'Adobe Ming Std',
#  'Courier New',
#  'Zapfino',
#  'Microsoft Sans Serif',
#  '.SF Compact Display',
#  'Consolas',
#  'STIXIntegralsUpSm',
#  'Mongolian Baiti',
#  '.SF Compact Rounded',
#  'Brush Script MT',
#  'Corbel',
#  'Nueva Std',
#  'Adobe Caslon Pro',
#  'Tw Cen MT',
#  'Candara',
#  'Letter Gothic Std',
#  'Trattatello',
#  'STIXIntegralsUpSm',
#  'Brush Script Std',
#  'STIXNonUnicode',
#  '.SF Compact Rounded',
#  'SimSun-ExtB',
#  'Apple Chancery',
#  '.SF Compact Text',
#  'Bookshelf Symbol 7',
#  'Arial Narrow',
#  'MingLiU',
#  'Myriad Pro',
#  'Tahoma',
#  'Courier New',
#  '.SF Compact Text',
#  '.SF Compact Text',
#  'Arial Narrow',
#  '.SF NS Display Condensed',
#  '.SF NS Display Condensed',
#  'Chalkduster',
#  'Adobe Hebrew',
#  'Comic Sans MS',
#  'Apple Braille',
#  'Franklin Gothic Book',
#  'Georgia',
#  'Constantia',
#  'Meiryo',
#  'Tekton Pro',
#  'Minion Pro',
#  'Minion Pro',
#  'Georgia',
#  'STIXGeneral',
#  'Rosewood Std',
#  'Adobe Song Std',
#  '.SF Compact Rounded',
#  'MS Reference Specialty',
#  'Adobe Arabic',
#  'Microsoft Himalaya',
#  'Adobe Caslon Pro',
#  '.SF NS Display Condensed',
#  'STIXSizeFourSym',
#  'Apple Braille',
#  'Khmer Sangam MN',
#  'STIXIntegralsUpD',
#  'Calibri',
#  'Letter Gothic Std',
#  'Meiryo',
#  'Gulim',
#  'Kozuka Mincho Pro',
#  'STIXGeneral',
#  'Trebuchet MS',
#  'Cooper Std',
#  'Adobe Devanagari',
#  'Wingdings 2',
#  'Nueva Std',
#  'STIXNonUnicode',
#  'Microsoft Tai Le',
#  'Myriad Pro',
#  'Big Caslon',
#  'Palatino Linotype',
#  'Trajan Pro',
#  'Myriad Hebrew',
#  'Adobe Caslon Pro',
#  'Tw Cen MT',
#  'Microsoft Yi Baiti',
#  '.SF Compact Text',
#  '.SF Compact Text',
#  '.SF Compact Rounded',
#  'Minion Pro',
#  'Lithos Pro',
#  'Tekton Pro',
#  '.SF Compact Display',
#  'Nueva Std',
#  'Stencil Std',
#  'Symbol',
#  'Georgia',
#  'Sathu',
#  'Constantia',
#  'Kozuka Mincho Pr6N',
#  'Adobe Kaiti Std',
#  'Marlett',
#  'Kozuka Gothic Pr6N',
#  'Krungthep',
#  'Times New Roman',
#  'Kozuka Mincho Pr6N',
#  'AppleMyungjo',
#  'Kozuka Gothic Pr6N',
#  'Minion Pro',
#  'Myriad Pro',
#  '.SF NS Display Condensed',
#  '.SF Compact Display',
#  'Nueva Std',
#  'Myriad Pro',
#  'System Font',
#  '.SF NS Text Condensed',
#  'Silom',
#  'STIXVariants',
#  'Kozuka Mincho Pr6N',
#  'Gill Sans MT',
#  'Adobe Myungjo Std',
#  'Gill Sans MT',
#  'Calibri',
#  'Blackoak Std',
#  'Trebuchet MS',
#  'MS Gothic',
#  'MS PGothic',
#  'Myriad Arabic',
#  'Kozuka Mincho Pro',
#  'Tekton Pro',
#  'Mishafi',
#  'Calibri',
#  'Mishafi Gold',
#  '.SF Compact Rounded',
#  'Apple Symbols',
#  'Consolas',
#  'Georgia',
#  'Diwan Thuluth',
#  'TeamViewer11',
#  'STIXGeneral',
#  'Minion Pro',
#  '.SF Compact Text',
#  'SimHei',
#  'Skia',
#  'Adobe Hebrew',
#  'DIN Condensed',
#  'Tw Cen MT',
#  'STIXIntegralsUp',
#  '.SF Compact Text',
#  'Hoefler Text',
#  'Cambria Math',
#  'Chaparral Pro',
#  'Cambria',
#  'Kozuka Gothic Pr6N',
#  '.SF NS Display Condensed',
#  '.SF Compact Rounded',
#  'Kozuka Mincho Pro',
#  'Bodoni 72 Smallcaps',
#  'STIXIntegralsUpD',
#  'Kozuka Gothic Pro',
#  'Adobe Devanagari',
#  'Franklin Gothic Medium',
#  'Courier New',
#  'MingLiU_HKSCS-ExtB',
#  '.SF NS Text Condensed',
#  'MS PMincho',
#  'Ayuthaya',
#  'Hobo Std',
#  'Adobe Caslon Pro',
#  'Constantia',
#  'STIXSizeOneSym',
#  'Kozuka Gothic Pro',
#  '.SF Compact Display',
#  'Adobe Hebrew',
#  '.SF Compact Text',
#  'Adobe Arabic',
#  'Trajan Pro',
#  'Kozuka Mincho Pro',
#  'Adobe Naskh',
#  'Adobe Hebrew',
#  'STIXIntegralsUp',
#  'Adobe Garamond Pro',
#  '.LastResort',
#  'STIXIntegralsSm',
#  'Tahoma',
#  'Lithos Pro',
#  'Microsoft Tai Le',
#  '.SF NS Display Condensed',
#  'Times New Roman',
#  'Comic Sans MS',
#  'Myriad Pro',
#  'Kozuka Gothic Pro',
#  'PMingLiU-ExtB',
#  'Chaparral Pro',
#  '.SF Compact Rounded',
#  '.SF NS Text Condensed',
#  'Farisi',
#  'Zapf Dingbats',
#  'Gill Sans MT',
#  'Myriad Hebrew',
#  'Andale Mono',
#  'Palatino Linotype',
#  '.SF Compact Rounded',
#  'Charlemagne Std',
#  'Kozuka Gothic Pro',
#  'MS Mincho',
#  'Adobe Gothic Std']

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')

fig = plt.figure(figsize=(4,3))
x = [1,2,3,4,5]
y = [123,432,823,192,12]

font1 = {'fontname':'Times New Roman'}
font2 = {'fontname':'Arial'}

plt.bar(x,y,align='center')
plt.title('Title',**font1) #標題名稱
plt.xlabel('X bar',**font1) #X軸名稱
plt.ylabel('Y bar',**font1) #Y軸名稱
plt.xticks(x, ['tick A','tick B','tick C','tick D','tick E'],**font2) #X軸刻度名稱

plt.show()

# %% [markdown]
# ## 4. 多圖合一

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')

plt.figure(figsize=(6,6))
x = [1,2,3,4,5]
y = [123,432,823,192,12]

ax1 = plt.subplot(211) #2x1的第1張圖
plt.plot(x,y,'-')
plt.setp(ax1.get_xticklabels(), visible=False) #不顯示x軸ticks
plt.subplot(212,sharex=ax1) #2x1的第2張圖
plt.bar(x,y,align='center')
plt.show()

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')

plt.figure(figsize=(6,6))
x = [1,2,3,4,5]
y = [123,432,823,192,12]
ax1=plt.subplot(211)
plt.plot(x,y,'-')
plt.setp(ax1.get_xticklabels(),visible=False)
plt.subplot(212,sharex=ax1)
plt.bar(x,y,align='center')
plt.show()

# %%
plt.figure(figsize=(5,3))
plt.plot(x,y,'-')
plt.bar(x,y,align='center')
plt.show()

# %% [markdown]
# ## 5. 折線圖種類

# %% [markdown]
# ##### color + style

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')

fig = plt.figure(figsize=(4,3))
x = [1,2,3,4,5]
y = [123,432,823,192,12]
plt.plot(x,y,'-')
plt.show()

# %%
fig = plt.figure(figsize=(4,3))
#plt.plot(x,y,'g--') #green
plt.plot(x,y,color='g',linestyle='--')
plt.show()

# %%
fig = plt.figure(figsize=(4,3))
plt.plot(x,y,'b-.') #blue
plt.show()

# %%
fig = plt.figure(figsize=(4,3))
plt.plot(x,y,'b-o') #blue
plt.show()

# %%
# 不連線的折線圖 => 散佈圖
fig = plt.figure(figsize=(4,3))
plt.plot(x,y,'*') #blue
plt.show()
